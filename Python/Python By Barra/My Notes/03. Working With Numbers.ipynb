# %% [markdown]
# # Types :

# %% [markdown]
# ## type() :

# %% [markdown]
# ## int() :

# %% [markdown]
# ## float() :

# %% [markdown]
# ## complex() :

# %% [markdown]
# # Math :

# %% [markdown]
# ## + - / // % *

# %% [markdown]
# # Rounding :

# %% [markdown]
# ## abs() :

# %% [markdown]
# ## round() :

# %% [markdown]
# ## math.ceil() :

# %% [markdown]
# ## math.floor() :

# %% [markdown]
# ## trunc() :

# %% [markdown]
# # Random :

# %% [markdown]
# ## random.random() :

# %% [markdown]
# ## randint() :

# %% [markdown]
# # Validating :

# %% [markdown]
# ## is_integer() :

# %% [markdown]
# ## isinstance() :
