# %% [markdown]
# # Loop :
# ```Repeat a block of code over and over until a condition is met.```

# %% [markdown]
# # FOR LOOP :

# %% [markdown]
# ## For Loop :

# %% [markdown]
# ## Statements :

# %% [markdown]
# ### Break :

# %% [markdown]
# ### Continue :

# %% [markdown]
# ### Pass :

# %% [markdown]
# ### Else :

# %% [markdown]
# ## Nested Loops :

# %% [markdown]
# # WHILE LOOP :

# %% [markdown]
# ## While Conditions :

# %% [markdown]
# ## While True :
