# %% [markdown]
# # Booleans :

# %% [markdown]
# ## True :

# %% [markdown]
# ## False :

# %% [markdown]
# ## Functions :

# %% [markdown]
# ### any() :

# %% [markdown]
# ### all() :

# %% [markdown]
# # Operators :

# %% [markdown]
# ## Membership Operators :

# %% [markdown]
# ### in :

# %% [markdown]
# ### not in :

# %% [markdown]
# ## Comparision Operators :

# %% [markdown]
# ### = , !=, <, >, <=, >= :

# %% [markdown]
# ## Logical Operators :

# %% [markdown]
# ### and :

# %% [markdown]
# ### or :

# %% [markdown]
# ### not :

# %% [markdown]
# ## Identity Operators :

# %% [markdown]
# ### is :

# %% [markdown]
# ### is not :
