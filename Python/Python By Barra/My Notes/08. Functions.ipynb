# %% [markdown]
# # Functions :

# %% [markdown]
# ```
# A function is a small, reusable block of code that does one specific task
# ```

# %% [markdown]
# ## Why Use Functions?

# %% [markdown]
# ```
# 1. Easy to change               (Solves Hard to change)
# 2. Fast Changes                 (Solves Time Consumptions in changing)
# 3. Safer (Low Risk)
# 4. Smaller and Clear codes
# 5. Esy to Read and Understand   (Solves Hard to read and Understand)
# 6. Modular
# 7. Collaborations
# ```

# %% [markdown]
# ## Sources of Functions :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Golden Rule to check when to write function :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How FUNCTION works?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types of Functions :

# %% [markdown]
# # Parameters :

# %% [markdown]
# ## Scope :

# %% [markdown]
# ### Parameters :

# %% [markdown]
# ### Local Variables :

# %% [markdown]
# ### Global Variables :

# %% [markdown]
# ## Default Parameter :

# %% [markdown]
# # Arguments :

# %% [markdown]
# ## Positional Arguments :

# %% [markdown]
# ## Keyword Arguments :

# %% [markdown]
# ## Mixed Arguments :

# %% [markdown]
# ## Flexibility :

# %% [markdown]
# ### *args :

# %% [markdown]
# ### **kwargs :

# %% [markdown]
# # Return :

# %% [markdown]
# # Types By Purpose :

# %% [markdown]
# ## Action :

# %% [markdown]
# ## Transformation :

# %% [markdown]
# ## Validation :

# %% [markdown]
# ## Orchestrator :

# %% [markdown]
# # Writing Clean Functions :
