# %% [markdown]
# # Types :

# %% [markdown]
# ## type() :

# %% [markdown]
# ## str() :

# %% [markdown]
# # Math :

# %% [markdown]
# ## len() :

# %% [markdown]
# ## count() :

# %% [markdown]
# # Data Transformation :

# %% [markdown]
# ## f{} :

# %% [markdown]
# ## + Combine :

# %% [markdown]
# ## replace() :

# %% [markdown]
# ## split() :

# %% [markdown]
# ## * Repeating :

# %% [markdown]
# ## Indexing & Slicing :

# %% [markdown]
# # Data Cleaning :

# %% [markdown]
# ## Remove Spaces :

# %% [markdown]
# ### rstrip() :

# %% [markdown]
# ### lstrip() :

# %% [markdown]
# ### strip() :

# %% [markdown]
# ## Case Conversion :

# %% [markdown]
# ### upper() :

# %% [markdown]
# ### lower() :

# %% [markdown]
# # Searching :

# %% [markdown]
# ## startswith() :

# %% [markdown]
# ## endswith() :

# %% [markdown]
# ## find() :

# %% [markdown]
# ## in Membership :

# %% [markdown]
# # Validating :

# %% [markdown]
# ## isalpha() :

# %% [markdown]
# ## isnumeric() :
