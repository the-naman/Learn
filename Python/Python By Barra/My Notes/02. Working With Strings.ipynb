# %% [markdown]
# # Chart :

# %% [markdown]
# ```
# Note :
#     1. Red Box : Built-in Functions
#     2. Blue Box : Methods of <str-class>
#     3. Yellow Box : Operators
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Types :

# %% [markdown]
# ## type() : returns the data type of a value

# %%
name = 'Naman'
print(type(name))
# Out:
# <class 'str'>

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ## str() : converts any value into string value

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
age = 25
# will throw error becuase (string + numeric) data type
print('Age is: ' + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 age = 25
#       2 # will throw error becuase (string + numeric) data type
# ----> 3 print('Age is: ' + age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 25
print('Age is: ' + str(age))
# Out:
# Age is: 25

# %%
age = 25
print(age)
# Out:
# 25

# %%
age = 25
age = age + 3
print(age)
# Out:
# 28

# %%
age = 25
age = str(age)
print(age)
print(type(age))
# Out:
# 25
# <class 'str'>

# %%
age = str(25)
print('Age = ' + age)
# Out:
# Age = 25

# %%
age = str(25)
print(type(age))
print(age)
print(age + 3)
# Out:
# <class 'str'>
# 25
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 age = str(25)
#       2 print(type(age))
#       3 print(age)
# ----> 4 print(age + 3)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# # Math :

# %% [markdown]
# ## len() : count everythings even spaces

# %%
password = '123hjhvbe4'
print(len(password))
# Out:
# 10

# %%
password = '  123hjhvbe4'
print(len(password))
# Out:
# 12

# %% [markdown]
# ## count() : returns how often a word appear in the string

# %% [markdown]
# ### Syntax :

# %% [markdown]
# ```
# text.count(substring)
# ```

# %%
text = """
Python is easy to learn.
Python is powerful.
many people love python.    
"""

# python != Python

print(text.count('Python'))
# Out:
# 2

# %% [markdown]
# # Data Transformation :

# %% [markdown]
# ## f{} - string: it is a modern, super-easy way to format and build strings, with this we can put variables, expressions directoly into the string

# %%
name = 'Sam'
age = 34
is_student = False


# using '+' operator and this is hard method
print("My name is " + name + ", I am " + str(age) +
      " years old and my student status is " + str(is_student) + '.')


# using f-string and this is easy method
print(
    f"My name is {name}, I am {age} years old and my student status is {is_student}.")
# Out:
# My name is Sam, I am 34 years old and my student status is False.
# My name is Sam, I am 34 years old and my student status is False.

# %%
print(f"{{for brackets we have to use it double}}")
# Out:
# {for brackets we have to use it double}

# %% [markdown]
# ## + Combine : joins or concatinates two strings into one

# %%
# full name
first_name = 'Kumar'
last_name = 'Naman'
full_name = first_name + ' ' + last_name
print(full_name)
# Out:
# Kumar Naman

# %%
# File path
folder = "C:/Users/Naman/"
filename = "report.csv"
file_path = folder + filename
print(file_path)
# Out:
# C:/Users/Naman/report.csv

# %% [markdown]
# ## replace() : swaps part of the text with something new

# %% [markdown]
# ### Syntax :

# %% [markdown]
# ```
# text.replace(old, new)
# ```

# %% [markdown]
# ### Practice :

# %%
price = '12345,98'
print('Old Format of Price:', price)
print('New Format of Price:', price.replace(',', '.'))
print("',' replcaed with '.'")
# Out:
# Old Format of Price: 12345,98
# New Format of Price: 12345.98
# ',' replcaed with '.'

# %%
# Date
d = '2026/08/15'
print(d)
# replace / with -
print(d.replace('/', '-'))
# Out:
# 2026/08/15
# 2026-08-15

# %%
# Mobile Number
MN = '987-853-1764'
print(MN)
# remove the - from whole mobile number
print(MN.replace('-', ""))
# Out:
# 987-853-1764
# 9878531764

# %%
price = '$1,265.99'
print(price)

# we want price as float without any sign or comma
print(price.replace('$', '').replace(',', ''))
# Out:
# $1,265.99
# 1265.99

# %% [markdown]
# ### Challenge :

# %% [markdown]
# #### Convert this "+49 (176) 123-4567" to "00491761234567".

# %%
pn = "+49 (176) 123-4567"
print('Phone Number =', pn)

print('Number:', pn.replace(
    '+', '00').replace(' (', '').replace(') ', '').replace('-', ''))
# Out:
# Phone Number = +49 (176) 123-4567
# Number: 00491761234567

# %% [markdown]
# ## split() : breaks a string into smaller parts

# %%
stamp = '2026-08-12 15:45:23'
print(f'stamp: {stamp}')

dt = stamp.split(' ')
print(f'Date and Time: {dt}')

d = dt[0]
print(
    f"Date: {d} ; ---->  Year: {d.split('-')[0]} ; Month: {d.split('-')[1]} ;   Date: {d.split('-')[2]}")

t = dt[1]
print(
    f'Time: {t} ;   ---->  Hours: {t.split(':')[0]} ;  Minutes: {t.split(':')[1]} ; Seconds: {t.split(':')[2]}')
# Out:
# stamp: 2026-08-12 15:45:23
# Date and Time: ['2026-08-12', '15:45:23']
# Date: 2026-08-12 ; ---->  Year: 2026 ; Month: 08 ;   Date: 12
# Time: 15:45:23 ;   ---->  Hours: 15 ;  Minutes: 45 ; Seconds: 23

# %%
csv_record = "1234,Max,USA,1970-10-05,M"
print(
    f"ID: {csv_record.split(',')[0]}\nName: {csv_record.split(',')[1]}\nCountry: {csv_record.split(',')[2]}\nDoB: {csv_record.split(',')[2]}\nGender: {csv_record.split(',')[3]}")
# Out:
# ID: 1234
# Name: Max
# Country: USA
# DoB: USA
# Gender: 1970-10-05

# %% [markdown]
# ## * Repeating : repeat the string multiple times

# %%
text = 'ha'
print(text * 3)
# Out:
# hahaha

# %%
formatter = '='
print(formatter * 30)

# %%
print('ha' * 4)
# Out:
# hahahaha

# %%
print('=' * 40)

# %% [markdown]
# ## Indexing & Slicing :

# %% [markdown]
# ### Chart :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Practice :

# %% [markdown]
# #### Indexing :

# %%
text = 'Python'
print(text[0])
print(text[-6])


print(text[5])
print(text[-1])

print(text[3])
print(text[-3])
# Out:
# P
# P
# n
# n
# h
# h

# %% [markdown]
# #### Slicing :

# %%
date = '2026-09-20'
print('Date :', date)

year = date[0:4]    # date[:4]
print('Year :', year)

month = date[5:7]
print('Month :', month)

day = date[-2:]     # date[8:10] or #date[8:]
print('Day : ', day)
# Out:
# Date : 2026-09-20
# Year : 2026
# Month : 09
# Day :  20

# %% [markdown]
# # Data Cleaning :

# %% [markdown]
# ## Remove Spaces :

# %% [markdown]
# ### rstrip() : removes spaces from the right side of the string

# %%
text = 'Python '
print(text)

print(text.rstrip())
# Out:
# Python
# Python

# %% [markdown]
# ### lstrip() : removes spaces from the left side of the string

# %%
text = ' Python'
print(text)

print(text.lstrip())
# Out:
#  Python
# Python

# %% [markdown]
# ### strip() : removes spaces from the both side of the string

# %%
text = '     Python '
print(text)

print(text.strip())
# Out:
#      Python
# Python

# %% [markdown]
# ### Advance use of strip()

# %%
# removing ## from ends
text = '###Python###'
print(text.strip('#'))
# Out:
# Python

# %%
# verifying spaces are or not is string
text = '   NAMAN '
print(f"Number of spaces in string = {len(text) - len(text.strip())}")
print(f"Is text clean? = {len(text) == len(text.strip())}")
# Out:
# Number of spaces in string = 4
# Is text clean? = False

# %%
# verifying spaces are or not is string
text = 'Python'
print(f"Number of spaces in string = {len(text) - len(text.strip())}")
print(f"Is text clean? = {len(text) == len(text.strip())}")
# Out:
# Number of spaces in string = 0
# Is text clean? = True

# %% [markdown]
# ## Case Conversion :

# %% [markdown]
# ### upper() : makes all letters to uppercase

# %%
text = 'python PROGRAMMING'
print(f"Text: {text}")
print(f"Converted Text : {text.upper()}")
# Out:
# Text: python PROGRAMMING
# Converted Text : PYTHON PROGRAMMING

# %% [markdown]
# ### lower() : makes all letters to lowercase

# %%
text = 'python PROGRAMMING'
print(f'text: {text}')
print(f'Convaerted Text: {text.lower()}')
# Out:
# text: python PROGRAMMING
# Convaerted Text: python programming

# %% [markdown]
# ## Challenge :

# %% [markdown]
# ### Write code to search = 'Email ' and data = ' emAil', but it returns TRUE because both have same meaninig.

# %%
search = 'Email '.lower().strip()
data = ' emAil'.lower().strip()

print(search == data)
# Out:
# True

# %% [markdown]
# # Searching :

# %% [markdown]
# ## startswith() :

# %% [markdown]
# ## endswith() :

# %% [markdown]
# ## find() :

# %% [markdown]
# ## in Membership :

# %% [markdown]
# # Validating :

# %% [markdown]
# ## isalpha() :

# %% [markdown]
# ## isnumeric() :
