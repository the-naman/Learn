# %% [markdown]
# # What is Python?

# %% [markdown]
# # How Python works?

# %% [markdown]
# # Why Learn Python?

# %% [markdown]
# # Comments

# %% [markdown]
# # print()

# %% [markdown]
# # Variables

# %% [markdown]
# # input()

# %% [markdown]
# # Data Types()
