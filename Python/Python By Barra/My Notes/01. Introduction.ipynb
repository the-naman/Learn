# %% [markdown]
# # What is Python?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How Python works?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Why Learn Python?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Comments

# %% [markdown]
# ```
# A comment is a future or helping note in your code.
# Python just skip it!
# ```

# %% [markdown]
# ## Why comments are powerful?

# %% [markdown]
# ```
# It makes our codes :
# 1. understandable
# 2. Readable
# 3. Professional
# ```

# %% [markdown]
# ## Types of comments :

# %% [markdown]
# ### Singe line or In line comments :

# %%
# This is a single line comment.

# %% [markdown]
# ### Multi-Line Comment :

# %%
"""
This
is 
a
Multi
Line
Comment.
"""

# Make a rule when ever writing multiline comment in VSCODE jupyter notebook, just add one more line below to that comment.

print('python')
# Out:
# python

# %% [markdown]
# ## Summary :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # print()

# %% [markdown]
# ```
# print() is a built-in python function that displays messages on the output screen to communicate with users.
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('-----------------------')
print("     Learn Python    ")
print('-----------------------')
# Out:
# -----------------------
#      Learn Python
# -----------------------

# %% [markdown]
# # What are Functions?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Variables

# %% [markdown]
# # input()

# %% [markdown]
# # Data Types()
