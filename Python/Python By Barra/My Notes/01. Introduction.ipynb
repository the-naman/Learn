# %% [markdown]
# # What is Python?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # How Python works?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Why Learn Python?

# %% [markdown]
# # Comments

# %% [markdown]
# # print()

# %% [markdown]
# # Variables

# %% [markdown]
# # input()

# %% [markdown]
# # Data Types()
