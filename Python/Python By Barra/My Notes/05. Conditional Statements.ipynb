# %% [markdown]
# # Conditional Statements :

# %% [markdown]
# ```
# Checkpoint that checks a condition :
#     If True : Run the Code
#     If False : Skip it
# ```

# %% [markdown]
# # Standalone If :

# %% [markdown]
# ## Chart :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1st condition If : If this is True, do this, otherwise, do nothing.

# %% [markdown]
# # Else :

# %% [markdown]
# # Elif :

# %% [markdown]
# # Nested If :

# %% [markdown]
# # Independent If :

# %% [markdown]
# # Inline If (Ternary) :

# %% [markdown]
# # Match Case :
