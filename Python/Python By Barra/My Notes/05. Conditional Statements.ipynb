# %% [markdown]
# # Standalone If :

# %% [markdown]
# # Else :

# %% [markdown]
# # Elif :

# %% [markdown]
# # Nested If :

# %% [markdown]
# # Independent If :

# %% [markdown]
# # Inline If (Ternary) :

# %% [markdown]
# # Match Case :
