# %% [markdown]
# # List - Fundamentals

# %% [markdown]
# # List - Advanced

# %% [markdown]
# ## Copy :

# %% [markdown]
# ### Assignment = :

# %% [markdown]
# ### copy() :

# %% [markdown]
# ### copy.deepcopy() :

# %% [markdown]
# ## Combine :

# %% [markdown]
# ## Iterators :

# %% [markdown]
# ## Comprehensions :

# %% [markdown]
# # Other Data Structures

# %% [markdown]
# ## Tuples :

# %% [markdown]
# ## Sets :

# %% [markdown]
# ## Dictionaries :
