# %% [markdown]
# # List - Fundamentals

# %% [markdown]
# ## Create :

# %% [markdown]
# ### [] :

# %% [markdown]
# ### list() :

# %% [markdown]
# ### manual :

# %% [markdown]
# ## Access and Read :

# %% [markdown]
# ### Indexing and Slicing :

# %% [markdown]
# ## Unpacking :

# %% [markdown]
# ### * Star Operator :

# %% [markdown]
# ### _ UnderScore Operator :

# %% [markdown]
# ## Explore and Analyzse :

# %% [markdown]
# ### max() :

# %% [markdown]
# ### min() :

# %% [markdown]
# ### sum() :

# %% [markdown]
# ### len() :

# %% [markdown]
# ### all() :

# %% [markdown]
# ### any() :

# %% [markdown]
# ### in Membership :

# %% [markdown]
# ### is Identity :

# %% [markdown]
# ### Comparision Operator :

# %% [markdown]
# ## Change :

# %% [markdown]
# ## Sorting :

# %% [markdown]
# ### sort() :

# %% [markdown]
# ### sort(reverse = True)

# %% [markdown]
# ### sorted() :

# %% [markdown]
# ### reverse() :

# %% [markdown]
# # List - Advanced

# %% [markdown]
# ## Copy :

# %% [markdown]
# ### Assignment = :

# %% [markdown]
# ### copy() :

# %% [markdown]
# ### copy.deepcopy() :

# %% [markdown]
# ## Combine :

# %% [markdown]
# ## Iterators :

# %% [markdown]
# ## Comprehensions :

# %% [markdown]
# # Other Data Structures

# %% [markdown]
# ## Tuples :

# %% [markdown]
# ## Sets :

# %% [markdown]
# ## Dictionaries :
