# %% [markdown]
# # WHERE {operators}
# ```
# 1. Comparision : (=, (!=, <>), >, >=, <, <=)
# 2. Logical : (AND, OR, NOT)
# 3. Range : (BETWEEN)
# 4. Membership : (IN, NOT IN)
# 5. Search : (LIKE)

# %% [markdown]
# ## 1. Comparision Operators :
