# %% [markdown]
# ## ALL COMMANDS:
# 1. CREATE : to craete the tables

# %% [markdown]
# ### DDL : DATA DEFINE LANGUAGE : Used to define or modify the data in table

# %% [markdown]
# #### CREATE : Used to create tables in Db

# %% [markdown]
# ##### Syntax :
# ```
#
# ```

# %% [markdown]
# ##### Task : Create a new table called Persons with columns (id, person_name, birth_date, and, phone)

# %%
# %%sql
# create table persons (
#     id INT NOT NULL,
#     person_name varchar(50) NOT NULL,
#     birth_date date,
#     phone VARCHAR(15) NOT NULL
# );
# Out:
# Running query in 'mysql+pymysql://'
# RuntimeError: (pymysql.err.OperationalError) (3750, "Unable to create or change a table without a primary key, when the system variable 'sql_require_primary_key' is set. Add a primary key to the table or unset this variable to avoid this message. Note that tables without a primary key can cause performance problems in row-based replication, so please consult your DBA before changing this setting.")
# [SQL: create table persons (
#     id INT NOT NULL,
#     person_name varchar(50) NOT NULL,
#     birth_date date,
#     phone VARCHAR(15) NOT NULL
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
