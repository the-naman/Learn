# %%
# Cell 1
# %load_ext sql

# %%
# Cell 2
import pymysql
from sqlalchemy import create_engine
import getpass

# password fetch code
# The 'r' ensures backslashes in Windows paths don't cause errors
file_path = r"E:\Study\Github\Sec\Secrets\DB Pass\p.txt"

# Open and read the file safely
with open(file_path, "r", encoding="utf-8") as file:
    secret_key = file.read().strip()  # .strip() removes accidental spaces or newlines


# continue

def get_conn():
    return pymysql.connect(
        host="onlinedb4me-onlinedb4me.c.aivencloud.com",
        user="avnadmin",
        password=secret_key,
        database="defaultdb",
        port=28393,
        ssl_ca=r"E:\Study\Github\Repositories\Learn\databases\DB For SQL by Baraa\AVN\CA SSL Cert\ca.pem"
    )

engine = create_engine("mysql+pymysql://", creator=get_conn)
# %sql engine
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 11
#       7 # The 'r' ensures backslashes in Windows paths don't cause errors
#       8 file_path = r"E:\Study\Github\Sec\DB Pass\p.txt"
#       9
#      10 # Open and read the file safely
# ---> 11 with open(file_path, "r", encoding="utf-8") as file:
#      12     secret_key = file.read().strip()  # .strip() removes accidental spaces or newlines
#      13
#      14
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\Study\\Github\\Sec\\DB Pass\\p.txt'

# %%
# %%sql
# SHOW DATABASES;
# Out:
# UsageError: No active connection.
#
# To fix it:
#
# Pass a valid connection string:
#     Example: %sql postgresql://username:password@hostname/dbname
#
# OR
#
# Set the environment variable $DATABASE_URL
#
# For more details, see: https://jupysql.ploomber.io/en/latest/connecting.html

# %%
# %%sql
# use MyDatabase;
# Out:
# Running query in 'mysql+pymysql://'
# ++
# ||
# ++
# ++

# %%
# %%sql
# show tables;
# Out:
# Running query in 'mysql+pymysql://'
# 2 rows affected.
# +----------------------+
# | Tables_in_MyDatabase |
# +----------------------+
# |      customers       |
# |        orders        |
# +----------------------+

# %%
# %%sql
# SHOW DATABASES;
# Out:
# UsageError: Cell magic `%%sql` not found.
