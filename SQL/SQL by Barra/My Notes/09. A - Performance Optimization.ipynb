# %% [markdown]
# # 1. Indexes :

# %% [markdown]
# ## Intro :

# %% [markdown]
# ### Definition :

# %% [markdown]
# ```
# INDEXES : Index is a DATA STURCTURE that provides quick access to data, optimizing the speed of your queries.
# ```

# %% [markdown]
# ## Types :

# %% [markdown]
# ### Visual :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Heap Structure :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## SUMMARY :

# %% [markdown]
# # 2. Partitions :

# %% [markdown]
# ## Intro :

# %% [markdown]
# ## Types :

# %% [markdown]
# ## SUMMARY :

# %% [markdown]
# # 3. Performance Tips :

# %% [markdown]
# ## Intro :

# %% [markdown]
# ## Types :

# %% [markdown]
# ## SUMMARY :
