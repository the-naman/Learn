# %%
# %run "000-connect_mysql.py"
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting and switching to connection 'mysql+pymysql://avnadmin:***@mysql-25ae1193-wk-f0bf.i.aivencloud.com:28242'
# ⚡ MySQL connection initialized successfully!

# %%
# %pip uninstall -y ipython-sql jupysql
# Out:
# Found existing installation: ipython-sql 0.5.0
# Uninstalling ipython-sql-0.5.0:
#   Successfully uninstalled ipython-sql-0.5.0
# Found existing installation: jupysql 0.11.1
# Uninstalling jupysql-0.11.1:
#   Successfully uninstalled jupysql-0.11.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install jupysql pymysql cryptography
# Out:
# Collecting jupysql
#   Using cached jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pymysql in g:\Softwares\Python 3\Lib\site-packages (1.2.0)
# Requirement already satisfied: cryptography in g:\Softwares\Python 3\Lib\site-packages (49.0.0)
# Requirement already satisfied: prettytable>=3.12.0 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (3.17.0)
# Requirement already satisfied: sqlalchemy in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (2.0.50)
# Requirement already satisfied: sqlparse in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (30.8.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in g:\Softwares\Python 3\Lib\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: cffi>=2.0.0 in g:\Softwares\Python 3\Lib\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in g:\Softwares\Python 3\Lib\site-packages (from cffi>=2.0.0->cryptography) (3.0)
# Requirement already satisfied: pyyaml in g:\Softwares\Python 3\Lib\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.3)
# Requirement already satisfied: posthog>=3.0 in g:\Softwares\Python 3\Lib\site-packages (from ploomber-core>=0.2.7->jupysql) (7.15.4)
# Requirement already satisfied: requests<3.0,>=2.7 in g:\Softwares\Python 3\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.34.2)
# Requirement already satisfied: backoff>=1.10.0 in g:\Softwares\Python 3\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in g:\Softwares\Python 3\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in g:\Softwares\Python 3\Lib\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in g:\Softwares\Python 3\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in g:\Softwares\Python 3\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in g:\Softwares\Python 3\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in g:\Softwares\Python 3\Lib\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2026.5.20)
# Requirement already satisfied: wcwidth in C:\Users\naman\AppData\Roaming\Python\Python314\site-packages (from prettytable>=3.12.0->jupysql) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in g:\Softwares\Python 3\Lib\site-packages (from jinja2->jupysql) (3.0.3)
# Requirement already satisfied: greenlet>=1 in g:\Softwares\Python 3\Lib\site-packages (from sqlalchemy->jupysql) (3.5.1)
# Using cached jupysql-0.11.1-py3-none-any.whl (95 kB)
# Installing collected packages: jupysql
# Successfully installed jupysql-0.11.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%sql
# show databases;
# Out:
# Running query in 'mysql+pymysql://avnadmin:***@mysql-25ae1193-wk-f0bf.i.aivencloud.com:28242'
# 6 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# |     MyDatabase     |
# |     defaultdb      |
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+

# %%
# %%sql
# CREATE DATABASE MyDatabase;
# USE MyDatabase;
#
# -- ======================================================
# -- Table: customers
# -- ======================================================
#
# CREATE TABLE customers (
#     id INT NOT NULL,
#     first_name VARCHAR(50),
#     country VARCHAR(50),
#     score INT,
#     PRIMARY KEY (id)
# );
#
# -- Insert customers data
# INSERT INTO customers (id, first_name, country, score) VALUES
#     (1, 'Maria', 'Germany', 350),
#     (2, ' John', 'USA', 900),
#     (3, 'Georg', 'UK', 750),
#     (4, 'Martin', 'Germany', 500),
#     (5, 'Peter', 'USA', 0);
#
# -- ======================================================
# -- Table: orders
# -- ======================================================
#
# CREATE TABLE orders (
#     order_id INT NOT NULL,
#     customer_id INT NOT NULL,
#     order_date DATE,
#     sales INT,
#     PRIMARY KEY (order_id)
# );
#
# -- Insert orders data
# INSERT INTO orders (order_id, customer_id, order_date, sales) VALUES
#     (1001, 1, '2021-01-11', 35),
#     (1002, 2, '2021-04-05', 15),
#     (1003, 3, '2021-06-18', 20),
#     (1004, 6, '2021-08-31', 10);
# Out:
# Running query in 'mysql+pymysql://avnadmin:***@mysql-25ae1193-wk-f0bf.i.aivencloud.com:28242'
# 1 rows affected.
# 5 rows affected.
# 4 rows affected.
# ++
# ||
# ++
# ++
