# %% [markdown]
# ## ALL COMMANDS:
# ```
# 1. INSERT : to insert data into a table : (INSERT INTO table_name (column1, column2, ...) VALUES (value1, value2, ...);)
# 2. INSERT using SELECT : to in_sert data in a table which data belongs to another table and we only select that much data which we need to insert. : (INSERT INTO target_table_name (col1, col2, col3, ....) SELECT col1, col2, col3, ... from source_table_name)
# 3. UPDATE : to update existing data within a table : (UPDATE table_name SET column1 = value1, column2 = value2 WHERE condition;)
# 4. DELETE : to delete records from a database table : (DELETE FROM table_name WHERE condition;)
# ```

# %% [markdown]
# ### *Description:*
# #### DML : Data Manipulation Language : Used to manipulate the data of the table in DB

# %% [markdown]
# ### INSERT : to insert / append values in the existing table

# %% [markdown]
# #### Syntax :
# ```
# INSERT INTO table_name (column1, column2, ...) VALUES (value1, value2, ...);
# ```

# %%
# %%sql
# desc customers;
# Out:
# Running query in 'mysql+pymysql://'
# 4 rows affected.
# +------------+-------------+------+-----+---------+-------+
# |   Field    |     Type    | Null | Key | Default | Extra |
# +------------+-------------+------+-----+---------+-------+
# |     id     |     int     |  NO  | PRI |   None  |       |
# | first_name | varchar(50) | YES  |     |   None  |       |
# |  country   | varchar(50) | YES  |     |   None  |       |
# |   score    |     int     | YES  |     |   None  |       |
# +------------+-------------+------+-----+---------+-------+

# %%
# %%sql
# select * from customers;
# Out:
# Running query in 'mysql+pymysql://'
# 5 rows affected.
# +----+------------+---------+-------+
# | id | first_name | country | score |
# +----+------------+---------+-------+
# | 1  |   Maria    | Germany |  350  |
# | 2  |    John    |   USA   |  900  |
# | 3  |   Georg    |    UK   |  750  |
# | 4  |   Martin   | Germany |  500  |
# | 5  |   Peter    |   USA   |   0   |
# +----+------------+---------+-------+

# %% [markdown]
# #### Insert one record as Anna from USA doesn't have any score in customer table.

# %%
# %%sql
# INSERT INTO customers (id, first_name, country, score)
# VALUES (6, 'Anna', 'USA', NULL);
# Out:
# Running query in 'mysql+pymysql://'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from customers;
# Out:
# Running query in 'mysql+pymysql://'
# 6 rows affected.
# +----+------------+---------+-------+
# | id | first_name | country | score |
# +----+------------+---------+-------+
# | 1  |   Maria    | Germany |  350  |
# | 2  |    John    |   USA   |  900  |
# | 3  |   Georg    |    UK   |  750  |
# | 4  |   Martin   | Germany |  500  |
# | 5  |   Peter    |   USA   |   0   |
# | 6  |    Anna    |   USA   |  None |
# +----+------------+---------+-------+

# %% [markdown]
# #### ADD multiple records in customer table as (1. Alie from UK having no score; 2. Sam having 100 score)

# %%
# %%sql
# INSERT INTO customers (id, first_name, country, score)
# VALUES (7, 'Alie', 'UK', NULL),
#     (8, 'Sam', NULL, 100);
# Out:
# Running query in 'mysql+pymysql://'
# 2 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from customers;
# Out:
# Running query in 'mysql+pymysql://'
# 8 rows affected.
# +----+------------+---------+-------+
# | id | first_name | country | score |
# +----+------------+---------+-------+
# | 1  |   Maria    | Germany |  350  |
# | 2  |    John    |   USA   |  900  |
# | 3  |   Georg    |    UK   |  750  |
# | 4  |   Martin   | Germany |  500  |
# | 5  |   Peter    |   USA   |   0   |
# | 6  |    Anna    |   USA   |  None |
# | 7  |    Alie    |    UK   |  None |
# | 8  |    Sam     |   None  |  100  |
# +----+------------+---------+-------+

# %% [markdown]
# #### Insert one record as (Andreas from Germany having no score) in customer table without mentioning column in query

# %%
# %%sql
# INSERT INTO customers
# VALUES (9, 'Andreas', 'Germany', NULL);
# Out:
# Running query in 'mysql+pymysql://'
# 1 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
# select * from customers;
# Out:
# Running query in 'mysql+pymysql://'
# 9 rows affected.
# +----+------------+---------+-------+
# | id | first_name | country | score |
# +----+------------+---------+-------+
# | 1  |   Maria    | Germany |  350  |
# | 2  |    John    |   USA   |  900  |
# | 3  |   Georg    |    UK   |  750  |
# | 4  |   Martin   | Germany |  500  |
# | 5  |   Peter    |   USA   |   0   |
# | 6  |    Anna    |   USA   |  None |
# | 7  |    Alie    |    UK   |  None |
# | 8  |    Sam     |   None  |  100  |
# | 9  |  Andreas   | Germany |  None |
# +----+------------+---------+-------+

# %% [markdown]
# ### INSERT using SELECT

# %% [markdown]
# #### RULE:
# ```
#
# ```

# %% [markdown]
# #### Copy the data from Customer table to Person table

# %%
# %%sql
# select * from customers
# Out:
# Running query in 'mysql+pymysql://'
# 9 rows affected.
# +----+------------+---------+-------+
# | id | first_name | country | score |
# +----+------------+---------+-------+
# | 1  |   Maria    | Germany |  350  |
# | 2  |    John    |   USA   |  900  |
# | 3  |   Georg    |    UK   |  750  |
# | 4  |   Martin   | Germany |  500  |
# | 5  |   Peter    |   USA   |   0   |
# | 6  |    Anna    |   USA   |  None |
# | 7  |    Alie    |    UK   |  None |
# | 8  |    Sam     |   None  |  100  |
# | 9  |  Andreas   | Germany |  None |
# +----+------------+---------+-------+

# %%
# %%sql
# select * from persons;
# Out:
# Running query in 'mysql+pymysql://'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (pymysql.err.ProgrammingError) (1146, "Table 'MyDatabase.persons' doesn't exist")
# [SQL: select * from persons;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
