# %% [markdown]
# <!-- TIER 1 SECTION -->
# <div style="background-color: #1e293b; padding: 12px; border-left: 6px solid #10b981; border-radius: 4px; margin-bottom: 20px;">
#     <h3 style="color: #10b981; margin: 0; font-family: sans-serif; font-size: 18px; font-weight: bold;">📋 Tier 1: Foundations (Syntax Mastery & Execution Order)</h3>
# </div>
#
# <div style="background-color: #14532d; padding: 6px 12px; border-radius: 4px; margin-top: 15px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #4ec9b0; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟢 DataLemur (Easy)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Data Science Skills** *(Easy - LinkedIn - Strict Filtering)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **Page Recommendations** *(Easy - Facebook - Outer Join Filtering)*
# </div>
#
# <div style="background-color: #14532d; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #4ec9b0; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟢 LeetCode (Easy)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 175:** Combine Two Tables *(Easy - Left Join Handling Nulls)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 181:** Employees Earning More Than Their Managers *(Easy - Self Joins)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 197:** Rising Temperature *(Easy - Date Manipulation)*
# </div>
#
# <div style="background-color: #7c2d12; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #ff9e7b; font-weight: bold; font-size: 13px; text-transform: uppercase;">🔵 HackerRank (Intermediate Basics)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **The Report** *(Intermediate - Basic Join & Non-Equi Joins)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Top Competitors** *(Intermediate - Basic Join & 4+ Table Merges)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 30px; border: 1px solid #3c3c3c;">
# - [ ] **The PADS** *(Intermediate - Advanced Select & String Formats)*
# </div>
#
#
# <!-- TIER 2 SECTION -->
# <div style="background-color: #1e293b; padding: 12px; border-left: 6px solid #3b82f6; border-radius: 4px; margin-bottom: 20px;">
#     <h3 style="color: #3b82f6; margin: 0; font-family: sans-serif; font-size: 18px; font-weight: bold;">📊 Tier 2: Business Logic & Analytical Puzzles (Medium Mastery)</h3>
# </div>
#
# <div style="background-color: #7c2d12; padding: 6px 12px; border-radius: 4px; margin-top: 15px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #ff9e7b; font-weight: bold; font-size: 13px; text-transform: uppercase;">🔵 HackerRank (Advanced Logic & Pivoting)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Occupations** *(Intermediate - Advanced Select & Data Pivoting)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **Binary Tree Nodes** *(Intermediate - Advanced Select & Hierarchical Logic)*
# </div>
#
# <div style="background-color: #7c2d12; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #ff9e7b; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟡 DataLemur (Medium)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **User's Third Transaction** *(Medium - Uber - Row_Number Partitioning)*
# </div>
#
# <div style="background-color: #7c2d12; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #ff9e7b; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟢 LeetCode (Medium)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 176:** Second Highest Salary *(Medium - Subqueries & Offsets)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 177:** Nth Highest Salary *(Medium - Dynamic Row Retrieval)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 178:** Rank Scores *(Medium - Dense_Rank vs Rank)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 184:** Department Highest Salary *(Medium - Aggregation Filtering)*
# </div>
#
# <div style="background-color: #7c2d12; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #ff9e7b; font-weight: bold; font-size: 13px; text-transform: uppercase;">🔴 StrataScratch (Medium Production Scaling)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Most Profitable Companies** *(Medium - Complex Sorting)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 30px; border: 1px solid #3c3c3c;">
# - [ ] **Users By Shopping Churn** *(Medium - Behavioral Analytics)*
# </div>
#
#
# <!-- TIER 3 SECTION -->
# <div style="background-color: #1e293b; padding: 12px; border-left: 6px solid #ef4444; border-radius: 4px; margin-bottom: 20px;">
#     <h3 style="color: #ef4444; margin: 0; font-family: sans-serif; font-size: 18px; font-weight: bold;">🚀 Tier 3: Advanced Optimization & State Tracking (Elite Tier)</h3>
# </div>
#
# <div style="background-color: #7a1d1d; padding: 6px 12px; border-radius: 4px; margin-top: 15px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #f44747; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟢 LeetCode (Hard & Dense Logical State Tracking)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 180:** Consecutive Numbers *(Medium - Lead/Lag Tracking)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 550:** Game Play Analysis IV *(Medium - Retention Metrics)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 185:** Department Top Three Salaries *(Hard - Dense Window Ranking)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 262:** Trips and Users *(Hard - Conditional Logic & Status Tracking)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **LeetCode 569:** Median Employee Salary *(Hard - Custom Partitioning Logic)*
# </div>
#
# <div style="background-color: #7a1d1d; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #f44747; font-weight: bold; font-size: 13px; text-transform: uppercase;">🔵 HackerRank (Complex Joins & Recursive Math)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Placements** *(Advanced - Advanced Join & Multi-Dependent Self-Joins)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Symmetric Pairs** *(Advanced - Advanced Join & Coordinate Comparisons)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Interviews** *(Advanced - Advanced Join & Multi-Table Aggregate Isolation)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **15 Days of Learning SQL** *(Advanced - Aggregations & Recursive Timelines)*
# </div>
#
# <div style="background-color: #7a1d1d; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #f44747; font-weight: bold; font-size: 13px; text-transform: uppercase;">🟡 DataLemur (Hard Metrics)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Active User Retention** *(Hard - Facebook - MoM Churn Metrics)*
# </div>
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 20px; border: 1px solid #3c3c3c;">
# - [ ] **Y-on-Y Growth Rate** *(Hard - Wayfair - Financial Timeline Lagging)*
# </div>
#
# <div style="background-color: #7a1d1d; padding: 6px 12px; border-radius: 4px; margin-top: 10px; margin-bottom: 10px; width: fit-content;">
#     <span style="color: #f44747; font-weight: bold; font-size: 13px; text-transform: uppercase;">🔴 StrataScratch (Hard Enterprise Schema Merges)</span>
# </div>
#
# <div style="background-color: #252526; padding: 8px 12px; border-radius: 4px; margin-bottom: 6px; border: 1px solid #3c3c3c;">
# - [ ] **Premium vs Freemium** *(Hard - Microsoft - Enterprise Schema Merges)*
# </div>
