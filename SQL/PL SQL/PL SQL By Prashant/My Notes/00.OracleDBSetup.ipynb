# %%
# !pip install ipython-sql oracledb
# Out:
# ...
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# ...
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [oracledb]
#    ---------------------------------------- 0/2 [oracledb]
#    ---------------------------------------- 0/2 [oracledb]
#    ---------------------------------------- 0/2 [oracledb]
#    ---------------------------------------- 0/2 [oracledb]
#    -------------------- ------------------- 1/2 [ipython-sql]
# ...

# %%
import oracledb

# Load the SQL magic extensions
# %load_ext sql

# Format: oracle+oracledb://username:password@hostname:port/?service_name=your_service
# %sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# RuntimeError: (oracledb.exceptions.OperationalError) DPY-6005: cannot connect to database (CONNECTION_ID=eCvTg5tle1MdP9jU6IrOJQ==).
# DPY-4011: the database or network closed the connection
# [WinError 10054] An existing connection was forcibly closed by the remote host
# Help: https://python-oracledb.readthedocs.io/en/latest/user_guide/troubleshooting.html#dpy-4011
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import oracledb

# 1. Ensure the magic extension is active
# %load_ext sql

# 2. Force JupySQL to disconnect from any old MySQL/mariadb sessions
# %sql --close all

# 3. Connect to Oracle Free (Replace 'your_password' with your actual password)
# %sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# RuntimeError: Could not close connection because it was not found amongst these: ['mysql+pymysql://']

# %%
# %reload_ext sql

# %%
import oracledb

# 1. Cleanly register and name your Oracle Free string engine
oracle_engine = %sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1

# 2. Tell JupySQL to explicitly swap its current focus to the Oracle engine
# %sql --activate oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1
# Out:
# RuntimeError: (oracledb.exceptions.OperationalError) DPY-6005: cannot connect to database (CONNECTION_ID=1zHxiXlcBM/vR8HcJd1MiQ==).
# DPY-4011: the database or network closed the connection
# [WinError 10054] An existing connection was forcibly closed by the remote host
# Help: https://python-oracledb.readthedocs.io/en/latest/user_guide/troubleshooting.html#dpy-4011
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1
# Out:
# RuntimeError: (oracledb.exceptions.OperationalError) DPY-6005: cannot connect to database (CONNECTION_ID=agbjwmzZmOcsQwVhQhBYrw==).
# DPY-4011: the database or network closed the connection
# [WinError 10054] An existing connection was forcibly closed by the remote host
# Help: https://python-oracledb.readthedocs.io/en/latest/user_guide/troubleshooting.html#dpy-4011
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %reload_ext sql

# %%
# %%sql
# --
# DECLARE
#     v_msg VARCHAR2(100);
# BEGIN
#     v_msg := 'PL/SQL is running successfully in Jupyter!';
#     DBMS_OUTPUT.PUT_LINE(v_msg);
# END;
# /
# Out:
# Running query in 'mysql+pymysql://'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'DECLARE\n    v_msg VARCHAR2(100)' at line 1")
# [SQL: DECLARE
#     v_msg VARCHAR2(100);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
import oracledb
import os
from dotenv import load_dotenv

load_dotenv()

local_dsn = "tcps://db.freesql.com:2484/26ai_un3c1"
connection = oracledb.connect(
    user="CON_V_I_C_TSDG_SCHEMA_BOHNN",
    password="qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU",
    dsn=local_dsn)

print("Successfully connected to Oracle Database")

cursor = connection.cursor()
for result in cursor.execute("SELECT * FROM DUAL"):
    print(result)
# Out:
# Successfully connected to Oracle Database
# ('X',)

# %%
# %%sql
# --
# DECLARE
#     v_msg VARCHAR2(100);
# BEGIN
#     v_msg := 'PL/SQL is running successfully in Jupyter!';
#     DBMS_OUTPUT.PUT_LINE(v_msg);
# END;
# Out:
# Running query in 'mysql+pymysql://'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'DECLARE\n    v_msg VARCHAR2(100)' at line 1")
# [SQL: DECLARE
#     v_msg VARCHAR2(100);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Cell 1: Install the required Oracle python driver if not already present
# !pip install oracledb

# Cell 2: Load the SQL magic extension
# %load_ext sql

# Cell 3: Connect using your FreeSQL.com credentials (replace with your details)
# Format: oracle+oracledb://username:password@host:port/?service_name=ORCL
# %sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1

# Cell 4: Execute PL/SQL using the %%sql magic (Requires an anonymous block or procedure)
# %%sql
DECLARE 
    v_version VARCHAR2(100);
BEGIN
    SELECT banner INTO v_version FROM v$version WHERE ROWNUM = 1;
    DBMS_OUTPUT.PUT_LINE('Connected to Oracle! Version: ' || v_version);
END;
/
# Out:
#   Cell In[28], line 14
#     v_version VARCHAR2(100);
#     ^
# IndentationError: unexpected indent

# %%
# %%sql
# DECLARE
#     v_version VARCHAR2(100);
# BEGIN
#     SELECT banner INTO v_version FROM v$version WHERE ROWNUM = 1;
#     DBMS_OUTPUT.PUT_LINE('Connected to Oracle! Version: ' || v_version);
# END;
# Out:
# Running query in 'mysql+pymysql://'
# RuntimeError: If using snippets, you may pass the --with argument explicitly.
# For more details please refer: https://jupysql.ploomber.io/en/latest/compose.html#with-argument
#
#
# Original error message from DB driver:
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'DECLARE\n    v_version VARCHAR2(100)' at line 1")
# [SQL: DECLARE
#     v_version VARCHAR2(100);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql oracle+oracledb://CON_V_I_C_TSDG_SCHEMA_BOHNN:qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU@db.freesql.com:2484/?service_name=26ai_un3c1
# DECLARE
#     v_version VARCHAR2(100);
# BEGIN
#     SELECT banner INTO v_version FROM v$version WHERE ROWNUM = 1;
#     DBMS_OUTPUT.PUT_LINE('Connected to Oracle! Version: ' || v_version);
# END;
# Out:
# RuntimeError: (oracledb.exceptions.OperationalError) DPY-6005: cannot connect to database (CONNECTION_ID=WGT9JeUBPbjnHpXg3MQfdA==).
# DPY-4011: the database or network closed the connection
# [WinError 10054] An existing connection was forcibly closed by the remote host
# Help: https://python-oracledb.readthedocs.io/en/latest/user_guide/troubleshooting.html#dpy-4011
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
import oracledb

# Create explicit parameters to force a secure TLS/SSL walletless handshake
params = oracledb.ConnectParams(
    user="CON_V_I_C_TSDG_SCHEMA_BOHNN",
    password="qOXP!U90EC17XYHNOJ7C6ZC2XJ6AWU",
    host="db.freesql.com",
    port=2484,
    # Make sure this matches your FreeSQL service panel string
    service_name="26ai_un3c1",
    protocol="tcps"  # Changes protocol from unencrypted TCP to secure TLS
)

# 1. Establish connection via Secure Thin Mode
connection = oracledb.connect(params=params)
print("Successfully bypassed network block via secure handshake!")

# 2. Setup database output listener
cursor = connection.cursor()
cursor.callproc("dbms_output.enable")

# Updated Step 3: Expand the string buffer variable to 4000 characters
plsql_block = """
DECLARE
    v_version VARCHAR2(4000); -- Expanded from 100 to 4000 to prevent ORA-06502
BEGIN
    SELECT banner INTO v_version FROM v$version WHERE ROWNUM = 1;
    DBMS_OUTPUT.PUT_LINE('Connected via Secure Thin Mode!');
    DBMS_OUTPUT.PUT_LINE('Version Details: ' || v_version);
END;
"""

# Step 4: Execute the block
cursor.execute(plsql_block)
print("PL/SQL block executed successfully without buffer overflow!")


while True:
    cursor.callproc("dbms_output.get_line", [line, status])
    if status.getvalue() != 0:
        break
    print(line.getvalue())

# 5. Close streams
cursor.close()
connection.close()
# Out:
# Successfully bypassed network block via secure handshake!
# PL/SQL block executed successfully without buffer overflow!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 39
#      35 print("PL/SQL block executed successfully without buffer overflow!")
#      36
#      37
#      38 while True:
# ---> 39     cursor.callproc("dbms_output.get_line", [line, status])
#      40     if status.getvalue() != 0:
#      41         break
#      42     print(line.getvalue())
#
# NameError: name 'line' is not defined

# %%
import oracledb

# 1. (Optional) Reconnect if your previous session timed out
# connection = oracledb.connect(params=params)

# 2. Setup database output listener
cursor = connection.cursor()
cursor.callproc("dbms_output.enable")

# 3. Define and execute your PL/SQL block with the large buffer
plsql_block = """
DECLARE
    v_version VARCHAR2(4000); 
BEGIN
    SELECT banner INTO v_version FROM v$version WHERE ROWNUM = 1;
    DBMS_OUTPUT.PUT_LINE('Connected via Secure Thin Mode!');
    DBMS_OUTPUT.PUT_LINE('Version Details: ' || v_version);
END;
"""
cursor.execute(plsql_block)
print("PL/SQL block executed successfully without buffer overflow!")

# 4. Declare the missing bind variables (Fixes the NameError)
status = cursor.var(oracledb.NUMBER)
line = cursor.var(oracledb.STRING)

# 5. Fetch and print the server buffer log safely
print("\n--- DBMS_OUTPUT Log ---")
while True:
    cursor.callproc("dbms_output.get_line", [line, status])
    if status.getvalue() != 0:
        break
    print(line.getvalue())

# 6. Clean up the streams
cursor.close()
connection.close()
# Out:
# PL/SQL block executed successfully without buffer overflow!
#
# --- DBMS_OUTPUT Log ---
# Connected via Secure Thin Mode!
# Version Details: Oracle AI Database 26ai EE Extreme Perf Release 23.26.0.0.0 - for Oracle Cloud and Engineered Systems
# Connected via Secure Thin Mode!
# Version Details: Oracle AI Database 26ai EE Extreme Perf Release 23.26.0.0.0 - for Oracle Cloud and Engineered Systems

# %%
DECLARE
    v_msg VARCHAR2(100);
BEGIN
    v_msg := 'PL/SQL is running successfully in Jupyter!';
    DBMS_OUTPUT.PUT_LINE(v_msg);
END;
/
# Out:
#   Cell In[39], line 2
#     v_msg VARCHAR2(100);
#     ^
# IndentationError: unexpected indent
